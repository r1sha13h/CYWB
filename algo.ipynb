# %%
import random as rn
print('random library imported')
# Out:
# random library imported

# %% [markdown]
# <b>Objective Function</b> : to calculate objective value

# %%
def obj(chromosome) :
    val = 0
    for i in range(1,len(chromosome)+1) : 
        val = val + i*chromosome[i-1]
        
    return abs(val-30)

print('Objectibe Function Defined')
# Out:
# Objectibe Function Defined

# %% [markdown]
# <b>Array Printer</b>

# %%
def printArray(array,string) : 
    for i in range(len(array)) : 
        print(string+'[',i,']'+' = ',array[i])

print('Array Printer Defined')
# Out:
# Array Printer Defined

# %% [markdown]
# <b>Matrix Printer <b>

# %%
def printMatrix(matrix) : 
    for i in range(len(matrix)) :
        print('Chromosome'+'[',i,']'+' = ',end = '')
        for j in matrix[i] :
            j = str(j)
            if len(j) < 2 : 
                j = '0'+j
            print(j,end = ' ')
        print()
        
print('Chromosome Printer Defined')
# Out:
# Chromosome Printer Defined

# %% [markdown]
# <b>Initialize Chromosome Population</b> : Assigns values(0-30) to chomosome population (matrix)

# %%
def initialize(size,gene) :
    chromosomeMatrix = []
    for i in range(size) :
        chromosome = []
        for j in range(gene) : 
            chromosome.append(rn.randrange(0,31,1))
            
        chromosomeMatrix.append(chromosome)
    
    return chromosomeMatrix

print('Initialisation Function Defined')
# Out:
# Initialisation Function Defined

# %% [markdown]
# <b>Selection Process</b> :
# <ul>
#     <li>Generates Next Generation Chromosome</li>
#     <li>Performs Crossover</li>
#     <li>Performs Mutation</li>
# </ul>

# %%
def selection(chromosomeMatrix) : 
    
    size = len(chromosomeMatrix)
    gene = len(chromosomeMatrix[0])
    
    # Compute Fitness Probability - Fitness[i]
    fitness = []
    for i in range(size) : 
        fitness.append(1/(1+obj(chromosomeMatrix[i])))
        
    print('Fitness')
    for fit in fitness : 
        print(round(fit,4),end = ' ')
    print('\n')
    
    # Compute Probability of Selection - P[i]
    total_fitness = sum(fitness)
    probability = []
    for i in range(size) : 
        probability.append(fitness[i]/total_fitness)
        
    print('Probability')
    for prob in probability : 
        print(round(prob,4),end = ' ')
    print('\n')

    # Calculate Cumulative Probability - C[i] 
    cum = 0
    cum_probability = [] 
    for i in range(size) : 
        cum = cum+probability[i]
        cum_probability.append(cum)
        
    print('Cumulative Probability')
    for prob in cum_probability : 
        print(round(prob,4),end = ' ')
    print('\n')
    
    # probability of selection process using roulette-wheel - R[i] 
    # In example given, R[i] generated is uniformily distributed
    # This may not happen in practical case as numbers(0-1) are generated purely using random function
    
    rouletteWheel = [rn.random() for i in range(size)]
    printArray(rouletteWheel,'R')
    print('\n')
    
    # Chromosome Population For next Generation
    newChromosomeMatrix = []
    for i in range(size) : 
        for j in range(size) : 
            if rouletteWheel[i] < cum_probability[j] : 
                newChromosomeMatrix.append(chromosomeMatrix[j].copy())
                break
    
    print('New Chromosomes - Next Generation')
    printMatrix(newChromosomeMatrix)
    print('\n')
    
    # selecting parent using random number and defining crossover rate
    parent = set()
    crossover_rate = 0.25
    randNum = []
    for i in range(size) : 
        randNum.append(rn.random())
        if randNum[i] < crossover_rate : 
            parent.add(i)
    
    print('Random Number')
    for r in randNum : 
        print(round(r,4),end = ' ')
    print('\n')
    
    parent = list(parent)
    no_of_parents = len(parent)
    
    print('Parents')
    for p in parent : 
        print(p,end = ' ')
    print()
    
    # determining the position of the crossover point
    crossOverPoint = [rn.randrange(1,size,1) for i in range(no_of_parents)]
    # parents Chromosome cut at crossover point and its genes interchanged
    for i in range(no_of_parents) : 
        newChromosomeMatrix[parent[i]] = (chromosomeMatrix[parent[i]][:crossOverPoint[i]+1] + 
                                          chromosomeMatrix[parent[(i+1)%no_of_parents]][crossOverPoint[i]+1 : ]).copy()
    
    print('Chromosome After Crossover')
    printMatrix(newChromosomeMatrix)
    print()
    
    # defining Mutation rate and generation of gene positions to perform mutation 
    mutation_rate = 0.1
    number_of_mutations = int(gene*size*mutation_rate)
    index = set()
    while(len(index) < number_of_mutations) : 
        index.add(rn.randrange(1,gene*size+1,1))
    
    # Performing Mutations
    index = list(index)
    while len(index) > 0 :
        count = index.pop()
        # Assigning random mutated values at positions generated
        newChromosomeMatrix[int((count-1)/gene)][(count-1)%gene] = rn.randrange(0,31,1)
    
    print('Chromosome Population after crossover and mutation')
    printMatrix(chromosomeMatrix)
    print()
    
    # Array to store objective function value to each chromosome of the population
    objectiveFunctionArray = []
    for i in range(size) : 
        objectiveFunctionArray.append(obj(newChromosomeMatrix[i]))
    
    print('Objective Function Value of each chromosome')
    for chromosome in chromosomeMatrix : 
        print(obj(chromosome),end = ' ')
    print('\n')
    
    return newChromosomeMatrix

print('Selection Function Defined')
# Out:
# Selection Function Defined

# %% [markdown]
# <b>FindMin : </b>Function to check if Chromosome Population has chromosome with minimised objective function value

# %%
def findMin(chromosomeMatrix) : 
    size = len(chromosomeMatrix)
    gene = len(chromosomeMatrix[0])
    found = False
    for i in range(size) : 
        if obj(chromosomeMatrix[i]) == 0 : 
            found = i
            break
    
    return found

print('Find Minimised Objective value - defined')
# Out:
# Find Minimised Objective value - defined

# %% [markdown]
# <b> MAIN </b>

# %%
if __name__ == '__main__' : 
    chromosomes = 6
    gene = 4
    chromosomeMatrix = initialize(chromosomes,gene)
    
    count = 0
    while not findMin(chromosomeMatrix) : 
        count = count+1
        print('Generation : ',count)
        chromosomeMatrix = selection(chromosomeMatrix)
        print('\nGeneration ',count,' ends.')
        print('\n\n\n\n\n')
# Out:
# Generation :  1
# Fitness
# 0.0079 0.0175 0.0323 0.0074 0.0192 0.008
#
# Probability
# 0.0853 0.19 0.3494 0.0802 0.2083 0.0867
#
# Cumulative Probability
# 0.0853 0.2753 0.6248 0.705 0.9133 1.0
#
# R[ 0 ] =  0.998156369787208
# R[ 1 ] =  0.18715038185158028
# R[ 2 ] =  0.34679679253945206
# R[ 3 ] =  0.5799852845724448
# R[ 4 ] =  0.8294222159895864
# R[ 5 ] =  0.5235351272218651
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 13 17 09 20
# Chromosome[ 1 ] = 18 12 00 11
# Chromosome[ 2 ] = 15 10 07 01
# Chromosome[ 3 ] = 15 10 07 01
# Chromosome[ 4 ] = 21 06 12 03
# Chromosome[ 5 ] = 15 10 07 01
#
#
# Random Number
# 0.881 0.8719 0.7764 0.6217 0.0203 0.3034
#
# Parents
# 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 13 17 09 20
# Chromosome[ 1 ] = 18 12 00 11
# Chromosome[ 2 ] = 15 10 07 01
# Chromosome[ 3 ] = 15 10 07 01
# Chromosome[ 4 ] = 21 06 12 03
# Chromosome[ 5 ] = 15 10 07 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 20 08 16 18
# Chromosome[ 1 ] = 18 12 00 11
# Chromosome[ 2 ] = 15 10 07 01
# Chromosome[ 3 ] = 11 10 15 22
# Chromosome[ 4 ] = 21 06 12 03
# Chromosome[ 5 ] = 13 17 09 20
#
# Objective Function Value of each chromosome
# 126 56 30 134 51 124
#
#
# Generation  1  ends.
#
#
#
#
#
#
# Generation :  2
# Fitness
# 0.008 0.0175 0.04 0.0103 0.0192 0.0323
#
# Probability
# 0.0628 0.1378 0.3141 0.081 0.151 0.2533
#
# Cumulative Probability
# 0.0628 0.2006 0.5147 0.5957 0.7467 1.0
#
# R[ 0 ] =  0.9221622228619017
# R[ 1 ] =  0.9114620716345598
# R[ 2 ] =  0.3853970787691522
# R[ 3 ] =  0.8905018566031984
# R[ 4 ] =  0.28836644712933346
# R[ 5 ] =  0.09325868952092153
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 10 07 01
# Chromosome[ 1 ] = 15 10 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 10 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 18 12 00 11
#
#
# Random Number
# 0.9472 0.0568 0.8993 0.315 0.9398 0.8667
#
# Parents
# 1
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 10 07 01
# Chromosome[ 1 ] = 18 12 00 11
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 10 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 18 12 00 11
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 13 17 09 20
# Chromosome[ 1 ] = 18 12 00 11
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 10 29 01
# Chromosome[ 4 ] = 21 06 12 03
# Chromosome[ 5 ] = 15 10 07 01
#
# Objective Function Value of each chromosome
# 124 56 24 96 51 30
#
#
# Generation  2  ends.
#
#
#
#
#
#
# Generation :  3
# Fitness
# 0.0175 0.0175 0.04 0.0323 0.04 0.0189
#
# Probability
# 0.1056 0.1056 0.2407 0.1941 0.2407 0.1135
#
# Cumulative Probability
# 0.1056 0.2111 0.4518 0.6458 0.8865 1.0
#
# R[ 0 ] =  0.017293910766076337
# R[ 1 ] =  0.271415861723723
# R[ 2 ] =  0.7935529556370564
# R[ 3 ] =  0.5286827337915072
# R[ 4 ] =  0.2082688070620865
# R[ 5 ] =  0.701759906750407
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 23 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 10 07 01
# Chromosome[ 4 ] = 18 12 00 11
# Chromosome[ 5 ] = 15 07 07 01
#
#
# Random Number
# 0.9718 0.7214 0.1606 0.82 0.4346 0.8509
#
# Parents
# 2
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 23 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 10 07 01
# Chromosome[ 4 ] = 18 12 00 11
# Chromosome[ 5 ] = 15 07 07 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 23 07 01
# Chromosome[ 1 ] = 18 12 00 11
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 10 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 14 12 00 11
#
# Objective Function Value of each chromosome
# 56 56 24 30 24 52
#
#
# Generation  3  ends.
#
#
#
#
#
#
# Generation :  4
# Fitness
# 0.0103 0.04 0.04 0.0323 0.0095 0.04
#
# Probability
# 0.0599 0.2324 0.2324 0.1874 0.0553 0.2324
#
# Cumulative Probability
# 0.0599 0.2923 0.5248 0.7122 0.7676 1.0
#
# R[ 0 ] =  0.11253218793267206
# R[ 1 ] =  0.8423442888527188
# R[ 2 ] =  0.20134261141070986
# R[ 3 ] =  0.8875518133493492
# R[ 4 ] =  0.7290124680591059
# R[ 5 ] =  0.2687505287072073
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 18 12 00 23
# Chromosome[ 5 ] = 15 07 07 01
#
#
# Random Number
# 0.7081 0.5817 0.3855 0.465 0.0879 0.7992
#
# Parents
# 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 18 12 00 23
# Chromosome[ 5 ] = 15 07 07 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 23 07 11
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 10 07 01
# Chromosome[ 4 ] = 18 12 00 23
# Chromosome[ 5 ] = 15 07 07 01
#
# Objective Function Value of each chromosome
# 96 24 24 30 104 24
#
#
# Generation  4  ends.
#
#
#
#
#
#
# Generation :  5
# Fitness
# 0.04 0.04 0.04 0.0164 0.0088 0.04
#
# Probability
# 0.216 0.216 0.216 0.0885 0.0474 0.216
#
# Cumulative Probability
# 0.216 0.432 0.6481 0.7366 0.784 1.0
#
# R[ 0 ] =  0.9486368727340954
# R[ 1 ] =  0.3252065016515594
# R[ 2 ] =  0.775614304723437
# R[ 3 ] =  0.35138421402531494
# R[ 4 ] =  0.8301969808170226
# R[ 5 ] =  0.49929112178142276
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 18 12 03 23
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 15 07 07 01
#
#
# Random Number
# 0.581 0.6327 0.5483 0.8105 0.841 0.3486
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 18 12 03 23
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 15 07 07 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 07 19 01
# Chromosome[ 4 ] = 18 12 03 23
# Chromosome[ 5 ] = 15 07 07 01
#
# Objective Function Value of each chromosome
# 24 24 24 60 113 24
#
#
# Generation  5  ends.
#
#
#
#
#
#
# Generation :  6
# Fitness
# 0.04 0.04 0.0091 0.04 0.011 0.04
#
# Probability
# 0.2221 0.2221 0.0505 0.2221 0.061 0.2221
#
# Cumulative Probability
# 0.2221 0.4442 0.4947 0.7169 0.7779 1.0
#
# R[ 0 ] =  0.5027346677417694
# R[ 1 ] =  0.17280984569732372
# R[ 2 ] =  0.7537858950897418
# R[ 3 ] =  0.060802649220764726
# R[ 4 ] =  0.08172398200396602
# R[ 5 ] =  0.46577358602040486
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 29 01
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 18 12 03 22
#
#
# Random Number
# 0.7829 0.5646 0.0329 0.5007 0.5855 0.0942
#
# Parents
# 2 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 18 12 03 22
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 15 07 03 22
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 18 12 03 22
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 29 01
# Chromosome[ 5 ] = 15 07 07 01
#
# Objective Function Value of each chromosome
# 24 24 109 24 90 24
#
#
# Generation  6  ends.
#
#
#
#
#
#
# Generation :  7
# Fitness
# 0.04 0.04 0.0088 0.04 0.0132 0.0103
#
# Probability
# 0.2626 0.2626 0.0581 0.2626 0.0864 0.0677
#
# Cumulative Probability
# 0.2626 0.5252 0.5833 0.8459 0.9323 1.0
#
# R[ 0 ] =  0.7396237923033977
# R[ 1 ] =  0.2712291769638395
# R[ 2 ] =  0.8143378624867298
# R[ 3 ] =  0.9134579347790482
# R[ 4 ] =  0.00014776389575132942
# R[ 5 ] =  0.6860595906391915
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 07 24 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 15 07 07 01
#
#
# Random Number
# 0.3703 0.4088 0.7069 0.696 0.18 0.1043
#
# Parents
# 4 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 07 24 01
# Chromosome[ 4 ] = 15 07 24 01
# Chromosome[ 5 ] = 15 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 18 12 04 22
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 24 01
# Chromosome[ 5 ] = 15 07 03 22
#
# Objective Function Value of each chromosome
# 24 24 112 24 75 96
#
#
# Generation  7  ends.
#
#
#
#
#
#
# Generation :  8
# Fitness
# 0.04 0.04 0.04 0.0132 0.0061 0.0769
#
# Probability
# 0.185 0.185 0.185 0.0609 0.0282 0.3558
#
# Cumulative Probability
# 0.185 0.3701 0.5551 0.616 0.6442 1.0
#
# R[ 0 ] =  0.11546020165097926
# R[ 1 ] =  0.1907652644666361
# R[ 2 ] =  0.6884924827663322
# R[ 3 ] =  0.2795064800912208
# R[ 4 ] =  0.28676392181133037
# R[ 5 ] =  0.9005136684435178
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 15 07 03 01
#
#
# Random Number
# 0.2438 0.2741 0.5565 0.2855 0.393 0.0895
#
# Parents
# 0 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 15 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 07 07 01
# Chromosome[ 1 ] = 15 07 07 01
# Chromosome[ 2 ] = 15 07 07 01
# Chromosome[ 3 ] = 15 07 24 01
# Chromosome[ 4 ] = 15 07 24 23
# Chromosome[ 5 ] = 15 07 03 01
#
# Objective Function Value of each chromosome
# 24 24 24 75 163 12
#
#
# Generation  8  ends.
#
#
#
#
#
#
# Generation :  9
# Fitness
# 0.0769 0.0714 0.0769 0.04 0.04 0.0175
#
# Probability
# 0.2383 0.2213 0.2383 0.1239 0.1239 0.0543
#
# Cumulative Probability
# 0.2383 0.4596 0.6978 0.8217 0.9457 1.0
#
# R[ 0 ] =  0.3637865459614227
# R[ 1 ] =  0.6475688035460109
# R[ 2 ] =  0.14543683849585476
# R[ 3 ] =  0.6118414833573831
# R[ 4 ] =  0.23758771932683964
# R[ 5 ] =  0.23912160128100668
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 04 07 07 01
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 04 07 07 01
#
#
# Random Number
# 0.4456 0.1216 0.7913 0.7414 0.2666 0.0435
#
# Parents
# 1 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 04 07 07 01
# Chromosome[ 1 ] = 04 07 07 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 29 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 04 07 07 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 07 01
# Chromosome[ 4 ] = 15 07 07 01
# Chromosome[ 5 ] = 15 29 03 01
#
# Objective Function Value of each chromosome
# 12 13 12 24 24 56
#
#
# Generation  9  ends.
#
#
#
#
#
#
# Generation :  10
# Fitness
# 0.0714 0.0071 0.0769 0.0769 0.0769 0.0175
#
# Probability
# 0.2185 0.0219 0.2353 0.2353 0.2353 0.0537
#
# Cumulative Probability
# 0.2185 0.2404 0.4757 0.711 0.9463 1.0
#
# R[ 0 ] =  0.015596421329938659
# R[ 1 ] =  0.3479940557810173
# R[ 2 ] =  0.7367218733137149
# R[ 3 ] =  0.3344729448768401
# R[ 4 ] =  0.7819088061181438
# R[ 5 ] =  0.5150638302532913
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 04 07 07 01
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 07 03 01
#
#
# Random Number
# 0.6523 0.6143 0.5323 0.6031 0.1532 0.3882
#
# Parents
# 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 04 07 07 01
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 04 07 07 01
# Chromosome[ 1 ] = 04 07 25 19
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 29 03 01
#
# Objective Function Value of each chromosome
# 13 139 12 12 12 56
#
#
# Generation  10  ends.
#
#
#
#
#
#
# Generation :  11
# Fitness
# 0.0192 0.0476 0.0769 0.0769 0.0769 0.0769
#
# Probability
# 0.0513 0.1271 0.2054 0.2054 0.2054 0.2054
#
# Cumulative Probability
# 0.0513 0.1785 0.3839 0.5892 0.7946 1.0
#
# R[ 0 ] =  0.4536943967109832
# R[ 1 ] =  0.17400450165237058
# R[ 2 ] =  0.5598074583763425
# R[ 3 ] =  0.8560763596754436
# R[ 4 ] =  0.8421324746482857
# R[ 5 ] =  0.9367973715506867
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 15 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 07 03 01
#
#
# Random Number
# 0.7452 0.977 0.0863 0.5874 0.491 0.8946
#
# Parents
# 2
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 15 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 04 26 07 01
# Chromosome[ 1 ] = 15 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 07 03 01
#
# Objective Function Value of each chromosome
# 51 20 12 12 12 12
#
#
# Generation  11  ends.
#
#
#
#
#
#
# Generation :  12
# Fitness
# 0.0769 0.0909 0.0769 0.0769 0.0345 0.0769
#
# Probability
# 0.1776 0.2099 0.1776 0.1776 0.0796 0.1776
#
# Cumulative Probability
# 0.1776 0.3875 0.5651 0.7428 0.8224 1.0
#
# R[ 0 ] =  0.8302221418110574
# R[ 1 ] =  0.17250185608223445
# R[ 2 ] =  0.05984755783065854
# R[ 3 ] =  0.3156308929644619
# R[ 4 ] =  0.7157527975511229
# R[ 5 ] =  0.5087347595826969
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 07 03 01
#
#
# Random Number
# 0.8424 0.6228 0.4368 0.364 0.8963 0.7071
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 05
# Chromosome[ 5 ] = 15 07 03 01
#
# Objective Function Value of each chromosome
# 12 10 12 12 28 12
#
#
# Generation  12  ends.
#
#
#
#
#
#
# Generation :  13
# Fitness
# 0.0769 0.0769 0.0125 0.0909 0.0769 0.0769
#
# Probability
# 0.1871 0.1871 0.0304 0.2211 0.1871 0.1871
#
# Cumulative Probability
# 0.1871 0.3742 0.4046 0.6258 0.8129 1.0
#
# R[ 0 ] =  0.5859094137173056
# R[ 1 ] =  0.3358857243691904
# R[ 2 ] =  0.9971602478321049
# R[ 3 ] =  0.5924251787124618
# R[ 4 ] =  0.4734757580848964
# R[ 5 ] =  0.5082349183932711
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 03
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 05 07 03 03
#
#
# Random Number
# 0.9754 0.87 0.9803 0.7683 0.507 0.1954
#
# Parents
# 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 03
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 15 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 22 07 23 01
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 15 07 03 01
#
# Objective Function Value of each chromosome
# 12 12 79 10 12 12
#
#
# Generation  13  ends.
#
#
#
#
#
#
# Generation :  14
# Fitness
# 0.0125 0.0769 0.0769 0.0435 0.0909 0.0769
#
# Probability
# 0.0331 0.2037 0.2037 0.1151 0.2407 0.2037
#
# Cumulative Probability
# 0.0331 0.2368 0.4405 0.5556 0.7963 1.0
#
# R[ 0 ] =  0.653745964631078
# R[ 1 ] =  0.3010752232367221
# R[ 2 ] =  0.27904603354749236
# R[ 3 ] =  0.8667754425474753
# R[ 4 ] =  0.5800298956412563
# R[ 5 ] =  0.14372482112638385
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 03
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 15 07 03 01
#
#
# Random Number
# 0.669 0.6645 0.9562 0.4484 0.6156 0.5413
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 03
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 15 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 26 03
# Chromosome[ 1 ] = 15 07 03 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 17 07 03 03
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 15 07 03 01
#
# Objective Function Value of each chromosome
# 79 12 12 22 10 12
#
#
# Generation  14  ends.
#
#
#
#
#
#
# Generation :  15
# Fitness
# 0.0909 0.0179 0.0769 0.0769 0.0909 0.0769
#
# Probability
# 0.2112 0.0415 0.1787 0.1787 0.2112 0.1787
#
# Cumulative Probability
# 0.2112 0.2527 0.4314 0.6101 0.8213 1.0
#
# R[ 0 ] =  0.7510629685512384
# R[ 1 ] =  0.029895058969990673
# R[ 2 ] =  0.14554341705338636
# R[ 3 ] =  0.12073999815226188
# R[ 4 ] =  0.8158357434562957
# R[ 5 ] =  0.3375740894451077
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 03
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 05 07 03 03
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 15 07 03 01
#
#
# Random Number
# 0.0842 0.7394 0.3851 0.2775 0.9719 0.7683
#
# Parents
# 0
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 03
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 05 07 03 03
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 15 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 03
# Chromosome[ 1 ] = 15 03 20 01
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 15 07 03 01
#
# Objective Function Value of each chromosome
# 10 55 12 12 10 12
#
#
# Generation  15  ends.
#
#
#
#
#
#
# Generation :  16
# Fitness
# 0.0435 0.0909 0.0182 0.0909 0.0909 0.0769
#
# Probability
# 0.1057 0.221 0.0442 0.221 0.221 0.187
#
# Cumulative Probability
# 0.1057 0.3267 0.3709 0.592 0.813 1.0
#
# R[ 0 ] =  0.9875026848612799
# R[ 1 ] =  0.3302859356570107
# R[ 2 ] =  0.9609550022413181
# R[ 3 ] =  0.9196808014762858
# R[ 4 ] =  0.9204502436682173
# R[ 5 ] =  0.730850676897413
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 05 07 03 14
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 05 07 03 03
#
#
# Random Number
# 0.1008 0.1489 0.3236 0.6418 0.2591 0.3977
#
# Parents
# 0 1
# Chromosome After Crossover
# Chromosome[ 0 ] = 17 07 03 03
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 07 03 01
# Chromosome[ 5 ] = 05 07 03 03
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 17 07 03 03
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 05 07 03 14
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 15 07 03 01
#
# Objective Function Value of each chromosome
# 22 10 54 10 10 12
#
#
# Generation  16  ends.
#
#
#
#
#
#
# Generation :  17
# Fitness
# 0.0435 0.0909 0.0769 0.0769 0.0588 0.0909
#
# Probability
# 0.0993 0.2076 0.1756 0.1756 0.1343 0.2076
#
# Cumulative Probability
# 0.0993 0.3068 0.4825 0.6581 0.7924 1.0
#
# R[ 0 ] =  0.7240066504320464
# R[ 1 ] =  0.9578282724246641
# R[ 2 ] =  0.3166750349247751
# R[ 3 ] =  0.9451090402106813
# R[ 4 ] =  0.2575291183199149
# R[ 5 ] =  0.18404321919250133
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 05 07 03 03
#
#
# Random Number
# 0.727 0.7384 0.466 0.4035 0.7976 0.7669
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 05 07 03 03
# Chromosome[ 4 ] = 05 07 03 03
# Chromosome[ 5 ] = 05 07 03 03
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 17 07 03 03
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 15 07 03 01
# Chromosome[ 4 ] = 15 09 03 01
# Chromosome[ 5 ] = 05 07 03 03
#
# Objective Function Value of each chromosome
# 22 10 12 12 16 10
#
#
# Generation  17  ends.
#
#
#
#
#
#
# Generation :  18
# Fitness
# 0.0588 0.0909 0.0769 0.0233 0.125 0.0909
#
# Probability
# 0.1263 0.1952 0.1651 0.0499 0.2683 0.1952
#
# Cumulative Probability
# 0.1263 0.3214 0.4866 0.5365 0.8048 1.0
#
# R[ 0 ] =  0.37696995597222316
# R[ 1 ] =  0.6320419174855447
# R[ 2 ] =  0.057304543478263525
# R[ 3 ] =  0.05002420788554951
# R[ 4 ] =  0.7478689308409647
# R[ 5 ] =  0.3717289580713342
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 15 07 03 01
# Chromosome[ 1 ] = 05 07 02 03
# Chromosome[ 2 ] = 15 09 03 01
# Chromosome[ 3 ] = 15 09 03 01
# Chromosome[ 4 ] = 05 07 02 03
# Chromosome[ 5 ] = 15 07 03 01
#
#
# Random Number
# 0.2355 0.6082 0.594 0.6225 0.574 0.2091
#
# Parents
# 0 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 02 03
# Chromosome[ 2 ] = 15 09 03 01
# Chromosome[ 3 ] = 15 09 03 01
# Chromosome[ 4 ] = 05 07 02 03
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 03 03
# Chromosome[ 2 ] = 15 07 03 01
# Chromosome[ 3 ] = 05 07 03 11
# Chromosome[ 4 ] = 05 07 02 03
# Chromosome[ 5 ] = 05 07 03 03
#
# Objective Function Value of each chromosome
# 16 10 12 42 7 10
#
#
# Generation  18  ends.
#
#
#
#
#
#
# Generation :  19
# Fitness
# 0.0588 0.0141 0.0588 0.0116 0.125 0.3333
#
# Probability
# 0.0978 0.0234 0.0978 0.0193 0.2077 0.554
#
# Cumulative Probability
# 0.0978 0.1212 0.2189 0.2383 0.446 1.0
#
# R[ 0 ] =  0.4870995542346602
# R[ 1 ] =  0.988157756720094
# R[ 2 ] =  0.035072668613114866
# R[ 3 ] =  0.47588611953400783
# R[ 4 ] =  0.031088909003706866
# R[ 5 ] =  0.978653874319082
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 15 09 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 15 09 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.1633 0.6272 0.5238 0.5308 0.8526 0.9582
#
# Parents
# 0
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 15 09 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 15 09 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 23 03
# Chromosome[ 2 ] = 15 09 03 01
# Chromosome[ 3 ] = 15 09 26 01
# Chromosome[ 4 ] = 05 07 02 03
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 16 70 16 85 7 2
#
#
# Generation  19  ends.
#
#
#
#
#
#
# Generation :  20
# Fitness
# 0.0588 0.3333 0.0588 0.25 0.0588 0.3333
#
# Probability
# 0.0538 0.3049 0.0538 0.2287 0.0538 0.3049
#
# Cumulative Probability
# 0.0538 0.3587 0.4126 0.6413 0.6951 1.0
#
# R[ 0 ] =  0.5676551131799046
# R[ 1 ] =  0.0860534438591487
# R[ 2 ] =  0.3299596185255461
# R[ 3 ] =  0.5062816325030228
# R[ 4 ] =  0.4085100961919469
# R[ 5 ] =  0.01675782479089305
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 09 02 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 09 02 01
# Chromosome[ 4 ] = 15 09 03 01
# Chromosome[ 5 ] = 15 09 03 01
#
#
# Random Number
# 0.0018 0.9119 0.9303 0.1484 0.169 0.0179
#
# Parents
# 0 3 4 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 09 03 01
# Chromosome[ 4 ] = 15 09 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 15 09 03 01
# Chromosome[ 3 ] = 05 09 02 01
# Chromosome[ 4 ] = 15 09 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 16 2 16 3 16 2
#
#
# Generation  20  ends.
#
#
#
#
#
#
# Generation :  21
# Fitness
# 0.0588 0.3333 0.3333 0.3333 0.0588 0.037
#
# Probability
# 0.0509 0.2887 0.2887 0.2887 0.0509 0.0321
#
# Cumulative Probability
# 0.0509 0.3396 0.6283 0.917 0.9679 1.0
#
# R[ 0 ] =  0.2059148780694211
# R[ 1 ] =  0.5079606744342787
# R[ 2 ] =  0.8635115543898153
# R[ 3 ] =  0.15430116714112008
# R[ 4 ] =  0.06769553783673743
# R[ 5 ] =  0.9649962185406251
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 05 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 15 09 03 01
#
#
# Random Number
# 0.3177 0.0964 0.0436 0.6171 0.7777 0.1704
#
# Parents
# 1 2 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 07
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 09 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 05 03 01
# Chromosome[ 4 ] = 15 09 03 01
# Chromosome[ 5 ] = 05 07 03 07
#
# Objective Function Value of each chromosome
# 16 2 2 2 16 26
#
#
# Generation  21  ends.
#
#
#
#
#
#
# Generation :  22
# Fitness
# 0.3333 0.0161 0.3333 0.3333 0.3333 0.037
#
# Probability
# 0.2404 0.0116 0.2404 0.2404 0.2404 0.0267
#
# Cumulative Probability
# 0.2404 0.252 0.4925 0.7329 0.9733 1.0
#
# R[ 0 ] =  0.13106661287750387
# R[ 1 ] =  0.8586744819186901
# R[ 2 ] =  0.1831740440899171
# R[ 3 ] =  0.42931745856381376
# R[ 4 ] =  0.7287397132275412
# R[ 5 ] =  0.5904129113957458
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.3048 0.9933 0.8104 0.525 0.8354 0.6287
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 28 07 15 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 07
#
# Objective Function Value of each chromosome
# 2 61 2 2 2 26
#
#
# Generation  22  ends.
#
#
#
#
#
#
# Generation :  23
# Fitness
# 0.3333 0.0286 0.0323 0.3333 0.3333 0.3333
#
# Probability
# 0.2391 0.0205 0.0231 0.2391 0.2391 0.2391
#
# Cumulative Probability
# 0.2391 0.2596 0.2827 0.5218 0.7609 1.0
#
# R[ 0 ] =  0.1147633457932179
# R[ 1 ] =  0.2061221574755182
# R[ 2 ] =  0.1760058712329643
# R[ 3 ] =  0.2769525898808082
# R[ 4 ] =  0.6766949589273576
# R[ 5 ] =  0.6154323892444805
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 08
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.1551 0.1976 0.1314 0.0743 0.6318 0.3894
#
# Parents
# 0 1 2 3
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 09
# Chromosome[ 1 ] = 05 07 03 09
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 09
# Chromosome[ 2 ] = 05 07 03 08
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 2 34 30 2 2 2
#
#
# Generation  23  ends.
#
#
#
#
#
#
# Generation :  24
# Fitness
# 0.0286 0.0141 0.3333 0.3333 0.0833 0.3333
#
# Probability
# 0.0254 0.0125 0.296 0.296 0.074 0.296
#
# Cumulative Probability
# 0.0254 0.0379 0.3339 0.63 0.704 1.0
#
# R[ 0 ] =  0.9896480032930024
# R[ 1 ] =  0.5892843337738018
# R[ 2 ] =  0.4031880027502812
# R[ 3 ] =  0.5012445450956096
# R[ 4 ] =  0.9749576861795372
# R[ 5 ] =  0.7285414504357054
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.7151 0.4689 0.6687 0.0104 0.7348 0.261
#
# Parents
# 3
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 09
# Chromosome[ 1 ] = 05 07 03 18
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 06 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 34 70 2 2 11 2
#
#
# Generation  24  ends.
#
#
#
#
#
#
# Generation :  25
# Fitness
# 0.3333 0.3333 0.0087 0.1111 0.3333 0.3333
#
# Probability
# 0.2294 0.2294 0.006 0.0765 0.2294 0.2294
#
# Cumulative Probability
# 0.2294 0.4588 0.4648 0.5412 0.7706 1.0
#
# R[ 0 ] =  0.3747193334010477
# R[ 1 ] =  0.8731097869581477
# R[ 2 ] =  0.21951839456344935
# R[ 3 ] =  0.8489675425754469
# R[ 4 ] =  0.8462180640028089
# R[ 5 ] =  0.391908565925532
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.1865 0.4837 0.9257 0.7717 0.8736 0.9237
#
# Parents
# 0
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 29
# Chromosome[ 3 ] = 05 07 05 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 2 2 114 8 2 2
#
#
# Generation  25  ends.
#
#
#
#
#
#
# Generation :  26
# Fitness
# 0.3333 0.3333 0.0526 0.125 0.3333 0.3333
#
# Probability
# 0.2206 0.2206 0.0348 0.0827 0.2206 0.2206
#
# Cumulative Probability
# 0.2206 0.4412 0.4761 0.5588 0.7794 1.0
#
# R[ 0 ] =  0.5232118097307414
# R[ 1 ] =  0.4296962086949986
# R[ 2 ] =  0.9271214243282013
# R[ 3 ] =  0.63203080189174
# R[ 4 ] =  0.6077387319230291
# R[ 5 ] =  0.5203006672791566
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 10 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 10 07 03 01
#
#
# Random Number
# 0.3563 0.8647 0.0765 0.5458 0.3831 0.1958
#
# Parents
# 2 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 10 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 15 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 15 03 01
# Chromosome[ 3 ] = 10 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 2 2 18 7 2 2
#
#
# Generation  26  ends.
#
#
#
#
#
#
# Generation :  27
# Fitness
# 0.0179 0.3333 0.0526 0.3333 0.3333 0.25
#
# Probability
# 0.0135 0.2524 0.0399 0.2524 0.2524 0.1893
#
# Cumulative Probability
# 0.0135 0.266 0.3058 0.5582 0.8107 1.0
#
# R[ 0 ] =  0.9938635886055703
# R[ 1 ] =  0.3895621222338592
# R[ 2 ] =  0.7420703678549919
# R[ 3 ] =  0.3260375034887999
# R[ 4 ] =  0.5561787362868839
# R[ 5 ] =  0.7946770301128266
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.0724 0.9118 0.7823 0.4216 0.1853 0.5545
#
# Parents
# 0 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 10 07 03 13
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 13
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 10 07 03 13
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 15 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 06 07 03 01
#
# Objective Function Value of each chromosome
# 55 2 18 2 2 3
#
#
# Generation  27  ends.
#
#
#
#
#
#
# Generation :  28
# Fitness
# 0.0096 0.3333 0.0169 0.3333 0.0196 0.3333
#
# Probability
# 0.0092 0.3186 0.0162 0.3186 0.0187 0.3186
#
# Cumulative Probability
# 0.0092 0.3278 0.344 0.6626 0.6814 1.0
#
# R[ 0 ] =  0.7367219910866443
# R[ 1 ] =  0.5896675264684582
# R[ 2 ] =  0.9726911935098377
# R[ 3 ] =  0.9347285217311605
# R[ 4 ] =  0.10472125604567195
# R[ 5 ] =  0.0629240051367741
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.4459 0.1232 0.1169 0.8507 0.8174 0.5938
#
# Parents
# 1 2
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 15
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 10 07 03 25
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 15
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 13
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 103 2 58 2 50 2
#
#
# Generation  28  ends.
#
#
#
#
#
#
# Generation :  29
# Fitness
# 0.3333 0.0182 0.3333 0.3333 0.0097 0.3333
#
# Probability
# 0.2449 0.0134 0.2449 0.2449 0.0071 0.2449
#
# Cumulative Probability
# 0.2449 0.2582 0.5031 0.748 0.7551 1.0
#
# R[ 0 ] =  0.11928933916879214
# R[ 1 ] =  0.9233620034922224
# R[ 2 ] =  0.9685620399776458
# R[ 3 ] =  0.8682132758496701
# R[ 4 ] =  0.7971100873158397
# R[ 5 ] =  0.9125377511092413
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.5796 0.3424 0.1744 0.5287 0.6745 0.9151
#
# Parents
# 2
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 05 03 15
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 26
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 2 54 2 2 102 2
#
#
# Generation  29  ends.
#
#
#
#
#
#
# Generation :  30
# Fitness
# 0.3333 0.3333 0.0476 0.3333 0.0256 0.3333
#
# Probability
# 0.237 0.237 0.0339 0.237 0.0182 0.237
#
# Cumulative Probability
# 0.237 0.474 0.5078 0.7448 0.763 1.0
#
# R[ 0 ] =  0.3306322208591119
# R[ 1 ] =  0.647073208800764
# R[ 2 ] =  0.761418893810255
# R[ 3 ] =  0.3958046060983269
# R[ 4 ] =  0.6293616306941939
# R[ 5 ] =  0.10526024251225408
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 25 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.1344 0.1344 0.5125 0.5125 0.146 0.418
#
# Parents
# 0 1 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 25 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 25 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 16 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 25 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 2 2 20 2 38 2
#
#
# Generation  30  ends.
#
#
#
#
#
#
# Generation :  31
# Fitness
# 0.3333 0.3333 0.011 0.3333 0.0263 0.3333
#
# Probability
# 0.2432 0.2432 0.008 0.2432 0.0192 0.2432
#
# Cumulative Probability
# 0.2432 0.4864 0.4944 0.7376 0.7568 1.0
#
# R[ 0 ] =  0.3799740520633006
# R[ 1 ] =  0.4109940445260577
# R[ 2 ] =  0.7244022285522702
# R[ 3 ] =  0.14974695040774189
# R[ 4 ] =  0.9435586270057327
# R[ 5 ] =  0.12222864381933218
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.5338 0.3381 0.7473 0.484 0.4522 0.0595
#
# Parents
# 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 25 03 14
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 04 25 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 2 2 90 2 37 2
#
#
# Generation  31  ends.
#
#
#
#
#
#
# Generation :  32
# Fitness
# 0.037 0.3333 0.1111 0.3333 0.3333 0.3333
#
# Probability
# 0.025 0.225 0.075 0.225 0.225 0.225
#
# Cumulative Probability
# 0.025 0.25 0.325 0.55 0.775 1.0
#
# R[ 0 ] =  0.5470342947832668
# R[ 1 ] =  0.6457800296187715
# R[ 2 ] =  0.9165944535756462
# R[ 3 ] =  0.06488398941869822
# R[ 4 ] =  0.7188749570149903
# R[ 5 ] =  0.3228091622257725
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 11 07 03 01
#
#
# Random Number
# 0.6067 0.0052 0.4756 0.9822 0.7585 0.6407
#
# Parents
# 1
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 11 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 11 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 11 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 26 2 8 2 2 2
#
#
# Generation  32  ends.
#
#
#
#
#
#
# Generation :  33
# Fitness
# 0.0556 0.3333 0.3333 0.3333 0.3333 0.1111
#
# Probability
# 0.037 0.2222 0.2222 0.2222 0.2222 0.0741
#
# Cumulative Probability
# 0.037 0.2593 0.4815 0.7037 0.9259 1.0
#
# R[ 0 ] =  0.5440303743578938
# R[ 1 ] =  0.49558961497800147
# R[ 2 ] =  0.4779747418567619
# R[ 3 ] =  0.9070189615476398
# R[ 4 ] =  0.896141996345831
# R[ 5 ] =  0.48257168097880343
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.9214 0.6732 0.2305 0.4296 0.8209 0.7865
#
# Parents
# 2
# Chromosome After Crossover
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 20 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 01 07 03 01
# Chromosome[ 5 ] = 11 07 03 01
#
# Objective Function Value of each chromosome
# 17 2 2 2 2 8
#
#
# Generation  33  ends.
#
#
#
#
#
#
# Generation :  34
# Fitness
# 0.3333 0.0278 0.0128 0.3333 0.3333 0.3333
#
# Probability
# 0.2426 0.0202 0.0093 0.2426 0.2426 0.2426
#
# Cumulative Probability
# 0.2426 0.2628 0.2722 0.5148 0.7574 1.0
#
# R[ 0 ] =  0.38768841586530256
# R[ 1 ] =  0.9619183942695008
# R[ 2 ] =  0.12788525027434117
# R[ 3 ] =  0.6615767847547634
# R[ 4 ] =  0.3380829811798679
# R[ 5 ] =  0.2977933221765159
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 03 01
# Chromosome[ 5 ] = 01 07 03 01
#
#
# Random Number
# 0.9091 0.8256 0.8748 0.9261 0.5308 0.625
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 03 01
# Chromosome[ 5 ] = 01 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 05 07 03 01
# Chromosome[ 1 ] = 05 07 14 01
# Chromosome[ 2 ] = 05 07 28 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 2 35 77 2 2 2
#
#
# Generation  34  ends.
#
#
#
#
#
#
# Generation :  35
# Fitness
# 0.3333 0.3333 0.3333 0.3333 0.0133 0.0588
#
# Probability
# 0.2372 0.2372 0.2372 0.2372 0.0095 0.0419
#
# Cumulative Probability
# 0.2372 0.4743 0.7115 0.9487 0.9581 1.0
#
# R[ 0 ] =  0.9952366049968151
# R[ 1 ] =  0.2197007785353724
# R[ 2 ] =  0.3209578986297139
# R[ 3 ] =  0.851793976195938
# R[ 4 ] =  0.8200053395353056
# R[ 5 ] =  0.7396628745005038
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 16 03 01
# Chromosome[ 1 ] = 01 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 03 01
# Chromosome[ 5 ] = 01 07 03 01
#
#
# Random Number
# 0.8925 0.3973 0.2011 0.4547 0.4713 0.6862
#
# Parents
# 2
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 16 03 01
# Chromosome[ 1 ] = 01 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 03 01
# Chromosome[ 5 ] = 01 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 03 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 03 20
# Chromosome[ 5 ] = 01 16 03 01
#
# Objective Function Value of each chromosome
# 2 2 2 2 74 16
#
#
# Generation  35  ends.
#
#
#
#
#
#
# Generation :  36
# Fitness
# 0.0588 0.3333 0.3333 0.3333 0.5 0.3333
#
# Probability
# 0.0311 0.1762 0.1762 0.1762 0.2642 0.1762
#
# Cumulative Probability
# 0.0311 0.2073 0.3834 0.5596 0.8238 1.0
#
# R[ 0 ] =  0.6291594366877951
# R[ 1 ] =  0.27980104454705546
# R[ 2 ] =  0.9293082599988498
# R[ 3 ] =  0.4881117888650446
# R[ 4 ] =  0.36207710702585805
# R[ 5 ] =  0.3550293340062889
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 01 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
#
# Random Number
# 0.633 0.9964 0.1329 0.0311 0.7151 0.2834
#
# Parents
# 2 3
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 16 03 01
# Chromosome[ 1 ] = 01 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 03 01
#
# Objective Function Value of each chromosome
# 16 2 2 2 1 2
#
#
# Generation  36  ends.
#
#
#
#
#
#
# Generation :  37
# Fitness
# 0.5 0.3333 0.3333 0.3333 0.0167 0.0169
#
# Probability
# 0.326 0.2174 0.2174 0.2174 0.0109 0.0111
#
# Cumulative Probability
# 0.326 0.5434 0.7607 0.9781 0.9889 1.0
#
# R[ 0 ] =  0.3029220187136106
# R[ 1 ] =  0.09855632942685089
# R[ 2 ] =  0.9395083597936381
# R[ 3 ] =  0.9355474669534382
# R[ 4 ] =  0.017710330199619095
# R[ 5 ] =  0.2674680415523485
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
#
# Random Number
# 0.9083 0.9407 0.0225 0.3481 0.4741 0.2199
#
# Parents
# 2 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 05 07 03 15
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 05 07 03 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 05 07 22 01
# Chromosome[ 5 ] = 05 07 03 15
#
# Objective Function Value of each chromosome
# 1 2 2 2 59 58
#
#
# Generation  37  ends.
#
#
#
#
#
#
# Generation :  38
# Fitness
# 0.5 0.1429 0.3333 0.3333 0.5 0.3333
#
# Probability
# 0.2333 0.0667 0.1556 0.1556 0.2333 0.1556
#
# Cumulative Probability
# 0.2333 0.3 0.4556 0.6111 0.8444 1.0
#
# R[ 0 ] =  0.789806303803188
# R[ 1 ] =  0.26527050960265
# R[ 2 ] =  0.29341335072843966
# R[ 3 ] =  0.3958132310690441
# R[ 4 ] =  0.8529246652725372
# R[ 5 ] =  0.0858124947912774
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 06 07 04 01
# Chromosome[ 2 ] = 06 07 04 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 05 07 03 01
# Chromosome[ 5 ] = 01 07 04 01
#
#
# Random Number
# 0.0445 0.5591 0.1583 0.7327 0.1588 0.7992
#
# Parents
# 0 2 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 06 07 04 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 06 07 04 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 01 07 03 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 05 07 03 01
#
# Objective Function Value of each chromosome
# 1 6 2 2 1 2
#
#
# Generation  38  ends.
#
#
#
#
#
#
# Generation :  39
# Fitness
# 0.5 0.1429 0.3333 0.0526 0.0161 0.5
#
# Probability
# 0.3236 0.0925 0.2158 0.0341 0.0104 0.3236
#
# Cumulative Probability
# 0.3236 0.4161 0.6319 0.6659 0.6764 1.0
#
# R[ 0 ] =  0.9156993710765186
# R[ 1 ] =  0.1293824823772547
# R[ 2 ] =  0.19532946254335437
# R[ 3 ] =  0.7779807919683992
# R[ 4 ] =  0.8779631503941656
# R[ 5 ] =  0.03892142395964393
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
#
# Random Number
# 0.4903 0.243 0.5992 0.3156 0.2263 0.4693
#
# Parents
# 1 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 06 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 24 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 06 07 04 01
# Chromosome[ 2 ] = 05 07 03 01
# Chromosome[ 3 ] = 05 07 03 05
# Chromosome[ 4 ] = 01 07 24 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Objective Function Value of each chromosome
# 1 6 2 18 61 1
#
#
# Generation  39  ends.
#
#
#
#
#
#
# Generation :  40
# Fitness
# 0.5 0.1429 0.0455 0.5 0.006 0.5
#
# Probability
# 0.2951 0.0843 0.0268 0.2951 0.0036 0.2951
#
# Cumulative Probability
# 0.2951 0.3794 0.4062 0.7013 0.7049 1.0
#
# R[ 0 ] =  0.046769644331833615
# R[ 1 ] =  0.6196626892005965
# R[ 2 ] =  0.46170765561184823
# R[ 3 ] =  0.033976643153453945
# R[ 4 ] =  0.2803018097041847
# R[ 5 ] =  0.8653362340201284
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
#
# Random Number
# 0.0572 0.7758 0.2174 0.1211 0.883 0.2572
#
# Parents
# 0 2 3
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 21 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 06 07 04 01
# Chromosome[ 2 ] = 21 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 24 27
# Chromosome[ 5 ] = 01 07 04 01
#
# Objective Function Value of each chromosome
# 1 6 21 1 165 1
#
#
# Generation  40  ends.
#
#
#
#
#
#
# Generation :  41
# Fitness
# 0.5 0.0179 0.0455 0.5 0.0286 0.5
#
# Probability
# 0.3141 0.0112 0.0286 0.3141 0.0179 0.3141
#
# Cumulative Probability
# ...
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 22 26
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Objective Function Value of each chromosome
# 1 1 1 155 1 1
#
#
# Generation  51  ends.
#
#
#
#
#
#
# Generation :  52
# Fitness
# 0.5 0.5 0.5 0.5 0.0714 0.0179
#
# Probability
# 0.2393 0.2393 0.2393 0.2393 0.0342 0.0085
#
# Cumulative Probability
# 0.2393 0.4786 0.7179 0.9573 0.9915 1.0
#
# R[ 0 ] =  0.5287546074653107
# R[ 1 ] =  0.4540482864861096
# R[ 2 ] =  0.1892414630401914
# R[ 3 ] =  0.025331746608432848
# R[ 4 ] =  0.6892814540500416
# R[ 5 ] =  0.3195731547081416
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
#
# Random Number
# 0.2219 0.9596 0.5126 0.7457 0.7417 0.7288
#
# Parents
# 0
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 04
# Chromosome[ 5 ] = 01 07 22 01
#
# Objective Function Value of each chromosome
# 1 1 1 1 13 55
#
#
# Generation  52  ends.
#
#
#
#
#
#
# Generation :  53
# Fitness
# 0.5 0.0714 0.5 0.5 0.5 0.05
#
# Probability
# 0.2357 0.0337 0.2357 0.2357 0.2357 0.0236
#
# Cumulative Probability
# 0.2357 0.2694 0.5051 0.7407 0.9764 1.0
#
# R[ 0 ] =  0.9700968836173198
# R[ 1 ] =  0.8484985352420589
# R[ 2 ] =  0.29378442477019484
# R[ 3 ] =  0.3305597127580675
# R[ 4 ] =  0.45037738890871015
# R[ 5 ] =  0.1803125780396847
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
#
# Random Number
# 0.2888 0.2652 0.457 0.5361 0.9155 0.4803
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 13 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 10 01
#
# Objective Function Value of each chromosome
# 1 13 1 1 1 19
#
#
# Generation  53  ends.
#
#
#
#
#
#
# Generation :  54
# Fitness
# 0.5 0.1111 0.5 0.0625 0.5 0.5
#
# Probability
# 0.23 0.0511 0.23 0.0288 0.23 0.23
#
# Cumulative Probability
# 0.23 0.2812 0.5112 0.5399 0.77 1.0
#
# R[ 0 ] =  0.6863219261810592
# R[ 1 ] =  0.4819684708836206
# R[ 2 ] =  0.7307924250713557
# R[ 3 ] =  0.07570462786687282
# R[ 4 ] =  0.8373084307622661
# R[ 5 ] =  0.0896237338724778
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
#
# Random Number
# 0.5481 0.7152 0.8678 0.8845 0.7343 0.8853
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 08 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 15 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Objective Function Value of each chromosome
# 1 8 1 15 1 1
#
#
# Generation  54  ends.
#
#
#
#
#
#
# Generation :  55
# Fitness
# 0.5 0.5 0.5 0.5 0.0833 0.3333
#
# Probability
# 0.2069 0.2069 0.2069 0.2069 0.0345 0.1379
#
# Cumulative Probability
# 0.2069 0.4138 0.6207 0.8276 0.8621 1.0
#
# R[ 0 ] =  0.5851369904611264
# R[ 1 ] =  0.46146741104160716
# R[ 2 ] =  0.9822799875970976
# R[ 3 ] =  0.6560027248918218
# R[ 4 ] =  0.7056668599208942
# R[ 5 ] =  0.1299331588673206
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 02 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
#
# Random Number
# 0.5401 0.9438 0.5567 0.3441 0.6918 0.7647
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 02 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 07 04 01
# Chromosome[ 1 ] = 01 07 04 01
# Chromosome[ 2 ] = 01 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 12 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
# Objective Function Value of each chromosome
# 1 1 1 1 11 2
#
#
# Generation  55  ends.
#
#
#
#
#
#
# Generation :  56
# Fitness
# 0.0417 0.0833 0.3333 0.5 0.5 0.5
#
# Probability
# 0.0213 0.0426 0.1702 0.2553 0.2553 0.2553
#
# Cumulative Probability
# 0.0213 0.0638 0.234 0.4894 0.7447 1.0
#
# R[ 0 ] =  0.05713038889211974
# R[ 1 ] =  0.05623905039922672
# R[ 2 ] =  0.05863854155903325
# R[ 3 ] =  0.27173012826792475
# R[ 4 ] =  0.25173050753998016
# R[ 5 ] =  0.1401724344148354
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 01 04 01
# Chromosome[ 1 ] = 01 01 04 01
# Chromosome[ 2 ] = 01 01 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
#
# Random Number
# 0.0401 0.1719 0.2044 0.0187 0.8973 0.5401
#
# Parents
# 0 1 2 3
# Chromosome After Crossover
# Chromosome[ 0 ] = 23 07 04 01
# Chromosome[ 1 ] = 01 01 04 01
# Chromosome[ 2 ] = 02 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 23 07 04 01
# Chromosome[ 1 ] = 01 01 04 01
# Chromosome[ 2 ] = 02 07 04 01
# Chromosome[ 3 ] = 01 07 04 01
# Chromosome[ 4 ] = 01 07 04 01
# Chromosome[ 5 ] = 01 07 04 01
#
# Objective Function Value of each chromosome
# 23 11 2 1 1 1
#
#
# Generation  56  ends.
#
#
#
#
#
#
# Generation :  57
# Fitness
# 0.0417 0.0833 0.3333 0.0102 0.25 0.3333
#
# Probability
# 0.0396 0.0792 0.3169 0.0097 0.2377 0.3169
#
# Cumulative Probability
# 0.0396 0.1188 0.4357 0.4454 0.6831 1.0
#
# R[ 0 ] =  0.14098867794821002
# R[ 1 ] =  0.9762956996068534
# R[ 2 ] =  0.2664704981576965
# R[ 3 ] =  0.5305928402592243
# R[ 4 ] =  0.8657195629293353
# R[ 5 ] =  0.1739194028782226
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 02 07 04 01
# Chromosome[ 1 ] = 02 07 04 01
# Chromosome[ 2 ] = 02 07 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 02 07 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
#
# Random Number
# 0.5424 0.6297 0.1742 0.5644 0.0205 0.5666
#
# Parents
# 2 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 02 07 04 01
# Chromosome[ 1 ] = 02 07 04 01
# Chromosome[ 2 ] = 02 07 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 23 07 04 01
# Chromosome[ 1 ] = 01 01 04 01
# Chromosome[ 2 ] = 02 07 04 01
# Chromosome[ 3 ] = 01 07 04 25
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
# Objective Function Value of each chromosome
# 23 11 2 97 3 2
#
#
# Generation  57  ends.
#
#
#
#
#
#
# Generation :  58
# Fitness
# 0.0588 0.3333 0.0105 0.25 0.25 0.3333
#
# Probability
# 0.0476 0.2697 0.0085 0.2023 0.2023 0.2697
#
# Cumulative Probability
# 0.0476 0.3173 0.3258 0.5281 0.7303 1.0
#
# R[ 0 ] =  0.07012312790339681
# R[ 1 ] =  0.6654527622471699
# R[ 2 ] =  0.705136890906284
# R[ 3 ] =  0.12712667361027474
# R[ 4 ] =  0.5734778411770607
# R[ 5 ] =  0.9437461528200517
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 02 07 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 02 07 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
#
# Random Number
# 0.2545 0.355 0.5066 0.7748 0.1367 0.574
#
# Parents
# 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 02 07 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 02 07 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 16 07 04 01
# Chromosome[ 1 ] = 02 07 04 01
# Chromosome[ 2 ] = 02 07 04 24
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 02 07 04 01
#
# Objective Function Value of each chromosome
# 16 2 94 3 3 2
#
#
# Generation  58  ends.
#
#
#
#
#
#
# Generation :  59
# Fitness
# 0.3333 0.25 0.25 0.3333 0.25 0.1111
#
# Probability
# 0.2182 0.1636 0.1636 0.2182 0.1636 0.0727
#
# Cumulative Probability
# 0.2182 0.3818 0.5455 0.7636 0.9273 1.0
#
# R[ 0 ] =  0.5506996270537755
# R[ 1 ] =  0.9556192449421365
# R[ 2 ] =  0.2815305582252412
# R[ 3 ] =  0.8988273860603367
# R[ 4 ] =  0.23120099483902068
# R[ 5 ] =  0.967081658057493
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 02 07 04 01
# Chromosome[ 1 ] = 04 01 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 04 01 04 01
#
#
# Random Number
# 0.5464 0.7582 0.9237 0.6154 0.546 0.9185
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 02 07 04 01
# Chromosome[ 1 ] = 04 01 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 04 01 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 02 07 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 02 07 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 04 01 04 01
#
# Objective Function Value of each chromosome
# 2 3 3 2 3 8
#
#
# Generation  59  ends.
#
#
#
#
#
#
# Generation :  60
# Fitness
# 0.0104 0.1111 0.25 0.25 0.25 0.1111
#
# Probability
# 0.0106 0.1131 0.2544 0.2544 0.2544 0.1131
#
# Cumulative Probability
# 0.0106 0.1237 0.3781 0.6325 0.8869 1.0
#
# R[ 0 ] =  0.7168470608617202
# R[ 1 ] =  0.8052320340295155
# R[ 2 ] =  0.16814895345010128
# R[ 3 ] =  0.7455892828480325
# R[ 4 ] =  0.0023311739394705766
# R[ 5 ] =  0.9811899784547922
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 15 07 04 21
# Chromosome[ 5 ] = 04 01 04 01
#
#
# Random Number
# 0.6506 0.7431 0.0256 0.0608 0.1038 0.9172
#
# Parents
# 2 3 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 04 01 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 15 07 04 21
# Chromosome[ 1 ] = 04 01 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 04 01 04 01
#
# Objective Function Value of each chromosome
# 95 8 3 3 3 8
#
#
# Generation  60  ends.
#
#
#
#
#
#
# Generation :  61
# Fitness
# 0.0106 0.25 0.25 0.25 0.0769 0.1111
#
# Probability
# 0.0112 0.2635 0.2635 0.2635 0.0811 0.1171
#
# Cumulative Probability
# 0.0112 0.2747 0.5383 0.8018 0.8829 1.0
#
# R[ 0 ] =  0.6237938259972424
# R[ 1 ] =  0.5022182307093813
# R[ 2 ] =  0.6748546033383735
# R[ 3 ] =  0.5654059983084607
# R[ 4 ] =  0.9250288213461464
# R[ 5 ] =  0.0026320373744773695
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 04 01 04 01
# Chromosome[ 5 ] = 01 05 04 25
#
#
# Random Number
# 0.0738 0.5781 0.5653 0.7985 0.1665 0.7114
#
# Parents
# 0 4
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 05 04 25
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 16 05 04 25
# Chromosome[ 5 ] = 01 05 04 25
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 05 04 25
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 16 05 04 01
# Chromosome[ 5 ] = 04 01 04 01
#
# Objective Function Value of each chromosome
# 93 3 3 3 12 8
#
#
# Generation  61  ends.
#
#
#
#
#
#
# Generation :  62
# Fitness
# 0.0106 0.25 0.25 0.0455 0.0092 0.0081
#
# Probability
# 0.0186 0.436 0.436 0.0793 0.016 0.0141
#
# Cumulative Probability
# 0.0186 0.4546 0.8907 0.9699 0.9859 1.0
#
# R[ 0 ] =  0.9773969459534265
# R[ 1 ] =  0.22601908391592684
# R[ 2 ] =  0.16036627800739622
# R[ 3 ] =  0.05093020254086733
# R[ 4 ] =  0.5735103614619704
# R[ 5 ] =  0.48208558854422623
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 16 05 04 25
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 04 01
#
#
# Random Number
# 0.6404 0.3505 0.1621 0.2712 0.5582 0.9031
#
# Parents
# 2
# Chromosome After Crossover
# Chromosome[ 0 ] = 16 05 04 25
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 05 04 25
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 17 04 01
# Chromosome[ 4 ] = 16 05 04 25
# Chromosome[ 5 ] = 01 20 04 25
#
# Objective Function Value of each chromosome
# 93 3 3 21 108 123
#
#
# Generation  62  ends.
#
#
#
#
#
#
# Generation :  63
# Fitness
# 0.0092 0.025 0.0833 0.25 0.25 0.25
#
# Probability
# 0.0106 0.0288 0.0961 0.2882 0.2882 0.2882
#
# Cumulative Probability
# 0.0106 0.0394 0.1355 0.4236 0.7118 1.0
#
# R[ 0 ] =  0.826351602214248
# R[ 1 ] =  0.45093334946807306
# R[ 2 ] =  0.3553639765602059
# R[ 3 ] =  0.2784972558196175
# R[ 4 ] =  0.7055110797402558
# R[ 5 ] =  0.15065250850885326
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 04 01
#
#
# Random Number
# 0.2816 0.0372 0.0536 0.0527 0.4713 0.584
#
# Parents
# 1 2 3
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 18 01
# Chromosome[ 2 ] = 01 12 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 04 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 16 05 04 25
# Chromosome[ 1 ] = 01 05 18 01
# Chromosome[ 2 ] = 01 12 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 04 01
#
# Objective Function Value of each chromosome
# 108 39 11 3 3 3
#
#
# Generation  63  ends.
#
#
#
#
#
#
# Generation :  64
# Fitness
# 0.25 0.025 0.0435 0.25 0.25 0.0217
#
# Probability
# 0.2975 0.0298 0.0517 0.2975 0.2975 0.0259
#
# Cumulative Probability
# 0.2975 0.3273 0.379 0.6766 0.9741 1.0
#
# R[ 0 ] =  0.5390171329442842
# R[ 1 ] =  0.7900256713646987
# R[ 2 ] =  0.4821655342972595
# R[ 3 ] =  0.3486791732105221
# R[ 4 ] =  0.4132249723573197
# R[ 5 ] =  0.3156639315556853
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 01 05 04 01
# Chromosome[ 3 ] = 12 12 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 18 01
#
#
# Random Number
# 0.2518 0.7381 0.2002 0.1602 0.1178 0.1188
#
# Parents
# 2 3 4 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 12 12 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 20 01
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 18 01
# Chromosome[ 2 ] = 12 12 04 01
# Chromosome[ 3 ] = 01 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 20 01
#
# Objective Function Value of each chromosome
# 3 39 22 3 3 45
#
#
# Generation  64  ends.

# %% [markdown]
# <b>RESULTS</b>

# %%
print('Number of Generations ->',count)
print('Best Chromosome obtained ->',chromosomeMatrix[findMin(chromosomeMatrix)])
# best chromosome is obtained when objective function becomes 0
print('Minimised Objective function for best Chromosome ->',0)
print('Final Chromosome Population')
printMatrix(chromosomeMatrix)
# Out:
# Number of Generations -> 64
# Best Chromosome obtained -> [4, 5, 4, 1]
# Minimised Objective function for best Chromosome -> 0
# Final Chromosome Population
# Chromosome[ 0 ] = 01 05 04 01
# Chromosome[ 1 ] = 01 05 04 01
# Chromosome[ 2 ] = 12 12 04 20
# Chromosome[ 3 ] = 04 05 04 01
# Chromosome[ 4 ] = 01 05 04 01
# Chromosome[ 5 ] = 01 05 20 01

# %% [markdown]
# <b>Few Points</b> :
# <ul>
#     <li>
# Above Chromosomes seem to be quiet uniform(similar gene values),this is due to low mutation rate, low mutation rate leads to fast convergence (less time to reach minimum objective function value).</li>
#     <li>
#         If mutation rate is kept high, values are quiet heterogenuous, but convergence might be slow.</li>
# </ul>
