# %%
import random as rn
print('random library imported')
# Out:
# random library imported

# %% [markdown]
# <b>Objective Function</b> : to calculate value of objective function

# %%
# objective function is
# f(a,b,c,d) = a+2b+3c+4d - 30
def obj(chromosome) :
    val = 0
    for i in range(1,len(chromosome)+1) : 
        val = val + i*chromosome[i-1]
        
    return abs(val-30)

print('Objectibe Function Defined')
# Out:
# Objectibe Function Defined

# %% [markdown]
# <b>Array Printer</b>

# %%
def printArray(array,string) : 
    for i in range(len(array)) : 
        print(string+'[',i,']'+' = ',array[i])

print('Array Printer Defined')
# Out:
# Array Printer Defined

# %% [markdown]
# <b>Matrix Printer <b>

# %%
def printMatrix(matrix) : 
    for i in range(len(matrix)) :
        print('Chromosome'+'[',i,']'+' = ',end = '')
        for j in matrix[i] :
            j = str(j)
            if len(j) < 2 : 
                j = '0'+j
            print(j,end = ' ')
        print()
        
print('Chromosome Printer Defined')
# Out:
# Chromosome Printer Defined

# %% [markdown]
# <b>Initialize Chromosome Population</b> : Assigns values(0-30) to chomosome population (matrix)

# %%
# size - population size = 6 (in given example)
# gene - no of genes in a chromosome = 4
def initialize(size,gene) :
    chromosomeMatrix = []
    for i in range(size) :
        chromosome = []
        for j in range(gene) : 
            chromosome.append(rn.randrange(0,31,1))
            
        chromosomeMatrix.append(chromosome)
    
    return chromosomeMatrix

print('Initialisation Function Defined')
# Out:
# Initialisation Function Defined

# %% [markdown]
# <b>Selection Process</b> :
# <ul>
#     <li>Generates Next Generation Chromosome</li>
#     <li>Performs Crossover</li>
#     <li>Performs Mutation</li>
# </ul>

# %%
def selection(chromosomeMatrix) : 
    
    # size - population size = 6 (in given example)
    # gene - no of genes in a chromosome = 4
    size = len(chromosomeMatrix)
    gene = len(chromosomeMatrix[0])
    
    # Compute Fitness Probability - Fitness[i]
    fitness = []
    for i in range(size) : 
        fitness.append(1/(1+obj(chromosomeMatrix[i])))
        
    print('Fitness')
    for fit in fitness : 
        print(round(fit,4),end = ' ')
    print('\n')
    
    # Compute Probability of Selection - P[i]
    total_fitness = sum(fitness)
    probability = []
    for i in range(size) : 
        probability.append(fitness[i]/total_fitness)
        
    print('Probability')
    for prob in probability : 
        print(round(prob,4),end = ' ')
    print('\n')

    # Calculate Cumulative Probability - C[i] 
    cum = 0
    cum_probability = [] 
    for i in range(size) : 
        cum = cum+probability[i]
        cum_probability.append(cum)
        
    print('Cumulative Probability')
    for prob in cum_probability : 
        print(round(prob,4),end = ' ')
    print('\n')
    
    # probability of selection process using roulette-wheel - R[i] 
    # In example given, R[i] generated is uniformily distributed
    # This may not happen in practical case as numbers(0-1) are generated purely using random function
    
    rouletteWheel = [rn.random() for i in range(size)]
    printArray(rouletteWheel,'R')
    print('\n')
    
    # Chromosome Population For next Generation
    newChromosomeMatrix = []
    for i in range(size) : 
        for j in range(size) : 
            if rouletteWheel[i] < cum_probability[j] : 
                newChromosomeMatrix.append(chromosomeMatrix[j].copy())
                break
    
    print('New Chromosomes - Next Generation')
    printMatrix(newChromosomeMatrix)
    print('\n')
    
    # selecting parent using random number and defining crossover rate
    parent = set()
    crossover_rate = 0.25
    randNum = []
    for i in range(size) : 
        randNum.append(rn.random())
        if randNum[i] < crossover_rate : 
            parent.add(i)
    
    print('Random Number')
    for r in randNum : 
        print(round(r,4),end = ' ')
    print('\n')
    
    parent = list(parent)
    no_of_parents = len(parent)
    
    print('Parents')
    for p in parent : 
        print(p,end = ' ')
    print()
    
    # determining the position of the crossover point
    crossOverPoint = [rn.randrange(1,size,1) for i in range(no_of_parents)]
    # parents Chromosome cut at crossover point and its genes interchanged
    for i in range(no_of_parents) : 
        newChromosomeMatrix[parent[i]] = (chromosomeMatrix[parent[i]][:crossOverPoint[i]+1] + 
                                          chromosomeMatrix[parent[(i+1)%no_of_parents]][crossOverPoint[i]+1 : ]).copy()
    
    print('Chromosome After Crossover')
    printMatrix(newChromosomeMatrix)
    print()
    
    # defining Mutation rate and generation of gene positions to perform mutation 
    mutation_rate = 0.1
    number_of_mutations = int(gene*size*mutation_rate)
    index = set()
    while(len(index) < number_of_mutations) : 
        index.add(rn.randrange(1,gene*size+1,1))
    
    # Performing Mutations
    index = list(index)
    while len(index) > 0 :
        count = index.pop()
        # Assigning random mutated values at positions generated
        newChromosomeMatrix[int((count-1)/gene)][(count-1)%gene] = rn.randrange(0,31,1)
    
    print('Chromosome Population after crossover and mutation')
    printMatrix(chromosomeMatrix)
    print()
    
    # Array to store objective function value to each chromosome of the population
    objectiveFunctionArray = []
    for i in range(size) : 
        objectiveFunctionArray.append(obj(newChromosomeMatrix[i]))
    
    print('Objective Function Value of each chromosome')
    for chromosome in chromosomeMatrix : 
        print(obj(chromosome),end = ' ')
    print('\n')
    
    return newChromosomeMatrix

print('Selection Function Defined')
# Out:
# Selection Function Defined

# %% [markdown]
# <b>FindMin : </b>Function to check if Chromosome Population has chromosome with minimised objective function value

# %%
def findMin(chromosomeMatrix) : 
    size = len(chromosomeMatrix)
    gene = len(chromosomeMatrix[0])
    found = False
    for i in range(size) : 
        if obj(chromosomeMatrix[i]) == 0 : 
            found = i
            break
    
    return found

print('Find Minimised Objective value - defined')
# Out:
# Find Minimised Objective value - defined

# %% [markdown]
# <b> MAIN </b>

# %%
if __name__ == '__main__' : 
    # size - population size = 6 (in given example)
    # gene - no of genes in a chromosome = 4
    size = 6
    gene = 4
    chromosomeMatrix = initialize(chromosomes,gene)
    
    count = 0
    while not findMin(chromosomeMatrix) : 
        count = count+1
        print('Generation : ',count)
        chromosomeMatrix = selection(chromosomeMatrix)
        print('\nGeneration ',count,' ends.')
        print('\n\n\n\n\n')
# Out:
# Generation :  1
# Fitness
# 0.0526 0.006 0.0068 0.006 0.0087 0.0435
#
# Probability
# 0.4262 0.0485 0.0547 0.0482 0.0704 0.352
#
# Cumulative Probability
# 0.4262 0.4746 0.5294 0.5775 0.648 1.0
#
# R[ 0 ] =  0.4465372750117258
# R[ 1 ] =  0.9202390489407098
# R[ 2 ] =  0.3460697523076488
# R[ 3 ] =  0.4864418127061506
# R[ 4 ] =  0.41425129007805606
# R[ 5 ] =  0.38489580683650426
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 20 27 18 17
# Chromosome[ 1 ] = 16 07 02 04
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 00 27 09 24
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 05 00 08
#
#
# Random Number
# 0.2181 0.7962 0.246 0.0839 0.3979 0.0595
#
# Parents
# 0 2 3 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 16 07 02 04
# Chromosome[ 2 ] = 00 27 09 24
# Chromosome[ 3 ] = 11 00 26 27
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 08
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 20 27 18 17
# Chromosome[ 2 ] = 00 27 09 24
# Chromosome[ 3 ] = 11 00 26 27
# Chromosome[ 4 ] = 16 25 06 15
# Chromosome[ 5 ] = 16 07 02 04
#
# Objective Function Value of each chromosome
# 18 166 147 167 114 22
#
#
# Generation  1  ends.
#
#
#
#
#
#
# Generation :  2
# Fitness
# 0.0526 0.0083 0.0068 0.006 0.0526 0.0256
#
# Probability
# 0.3464 0.0548 0.0445 0.0392 0.3464 0.1688
#
# Cumulative Probability
# 0.3464 0.4012 0.4457 0.4849 0.8312 1.0
#
# R[ 0 ] =  0.3350564585536323
# R[ 1 ] =  0.4053133013469641
# R[ 2 ] =  0.8757898156743734
# R[ 3 ] =  0.6212164204585083
# R[ 4 ] =  0.3344614512135917
# R[ 5 ] =  0.8348074114225195
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 00 27 09 24
# Chromosome[ 2 ] = 16 07 02 08
# Chromosome[ 3 ] = 06 05 00 08
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 08
#
#
# Random Number
# 0.4071 0.9642 0.6834 0.5375 0.3327 0.9662
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 00 27 09 24
# Chromosome[ 2 ] = 16 07 02 08
# Chromosome[ 3 ] = 06 05 00 08
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 08
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 16 18 27 04
# Chromosome[ 2 ] = 00 27 09 24
# Chromosome[ 3 ] = 11 00 26 27
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 08
#
# Objective Function Value of each chromosome
# 18 119 147 167 18 38
#
#
# Generation  2  ends.
#
#
#
#
#
#
# Generation :  3
# Fitness
# 0.0526 0.0048 0.0256 0.0149 0.0526 0.0256
#
# Probability
# 0.2986 0.0273 0.1455 0.0847 0.2986 0.1455
#
# Cumulative Probability
# 0.2986 0.3258 0.4713 0.556 0.8545 1.0
#
# R[ 0 ] =  0.8921387434963859
# R[ 1 ] =  0.3199953888575886
# R[ 2 ] =  0.5743094398278474
# R[ 3 ] =  0.4366726666941856
# R[ 4 ] =  0.8948657756331572
# R[ 5 ] =  0.6742324066532779
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 16 07 02 08
# Chromosome[ 1 ] = 00 27 29 24
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 16 07 02 08
# Chromosome[ 4 ] = 16 07 02 08
# Chromosome[ 5 ] = 06 05 00 08
#
#
# Random Number
# 0.5825 0.6932 0.6575 0.1602 0.1174 0.1478
#
# Parents
# 3 4 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 16 07 02 08
# Chromosome[ 1 ] = 00 27 29 24
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 20
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 20
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 00 27 29 24
# Chromosome[ 2 ] = 16 07 02 08
# Chromosome[ 3 ] = 06 05 00 20
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 08
#
# Objective Function Value of each chromosome
# 18 207 38 66 18 38
#
#
# Generation  3  ends.
#
#
#
#
#
#
# Generation :  4
# Fitness
# 0.0278 0.0048 0.0526 0.0127 0.0526 0.0115
#
# Probability
# 0.1715 0.0297 0.3249 0.0781 0.3249 0.071
#
# Cumulative Probability
# 0.1715 0.2011 0.526 0.6042 0.929 1.0
#
# R[ 0 ] =  0.23234667411289123
# R[ 1 ] =  0.40419606347440473
# R[ 2 ] =  0.4953603023618417
# R[ 3 ] =  0.5786919116635818
# R[ 4 ] =  0.6450474518684562
# R[ 5 ] =  0.6784655782572835
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 06 05 00 08
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 23
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 05 00 08
#
#
# Random Number
# 0.3983 0.2323 0.0232 0.8815 0.8726 0.1426
#
# Parents
# 1 2 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 00 27 00 08
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 23
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 20
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 13 07 02 08
# Chromosome[ 1 ] = 00 27 29 24
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 23
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 20
#
# Objective Function Value of each chromosome
# 35 207 18 78 18 86
#
#
# Generation  4  ends.
#
#
#
#
#
#
# Generation :  5
# Fitness
# 0.1429 0.0175 0.0526 0.0127 0.0526 0.0196
#
# Probability
# 0.4795 0.0589 0.1767 0.0425 0.1767 0.0658
#
# Cumulative Probability
# 0.4795 0.5384 0.715 0.7575 0.9342 1.0
#
# R[ 0 ] =  0.43483986686144127
# R[ 1 ] =  0.7734314485724822
# R[ 2 ] =  0.3302691464294317
# R[ 3 ] =  0.6009664027133609
# R[ 4 ] =  0.8590781410648347
# R[ 5 ] =  0.1196939759126423
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 06 05 00 08
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 06 05 00 08
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 05 00 05
#
#
# Random Number
# 0.2238 0.8543 0.1062 0.8015 0.8688 0.6644
#
# Parents
# 0 2
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 06 05 00 08
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 08
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 05 00 05
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 00 27 00 08
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 23
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 16 07 02 11
#
# Objective Function Value of each chromosome
# 6 56 18 78 18 50
#
#
# Generation  5  ends.
#
#
#
#
#
#
# Generation :  6
# Fitness
# 0.1429 0.0086 0.0526 0.0526 0.0526 0.1429
#
# Probability
# 0.3159 0.0191 0.1164 0.1164 0.1164 0.3159
#
# Cumulative Probability
# 0.3159 0.335 0.4513 0.5677 0.6841 1.0
#
# R[ 0 ] =  0.6588441449986796
# R[ 1 ] =  0.41916023259106916
# R[ 2 ] =  0.4066586544141154
# R[ 3 ] =  0.7824680596684292
# R[ 4 ] =  0.8958563140094653
# R[ 5 ] =  0.9661042094691981
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 06 05 00 08
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 05
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 05 00 05
#
#
# Random Number
# 0.0641 0.0771 0.416 0.4809 0.5034 0.3222
#
# Parents
# 0 1
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 16 05 29 05
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 05
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 05 00 05
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 16 05 29 08
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 08
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 05 00 05
#
# Objective Function Value of each chromosome
# 6 115 18 18 18 6
#
#
# Generation  6  ends.
#
#
#
#
#
#
# Generation :  7
# Fitness
# 0.0526 0.0077 0.0526 0.1429 0.1429 0.0714
#
# Probability
# 0.112 0.0164 0.112 0.3039 0.3039 0.1519
#
# Cumulative Probability
# 0.112 0.1283 0.2403 0.5442 0.8481 1.0
#
# R[ 0 ] =  0.749278987490715
# R[ 1 ] =  0.4015693680181289
# R[ 2 ] =  0.35359120393036714
# R[ 3 ] =  0.8840634426043078
# R[ 4 ] =  0.06802275912677547
# R[ 5 ] =  0.19852946111706082
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 06 05 00 05
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 13 05 00 05
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 05 00 08
#
#
# Random Number
# 0.0987 0.0212 0.4975 0.4634 0.7633 0.6461
#
# Parents
# 0 1
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 16 18 29 05
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 13 05 00 05
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 05 00 08
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 16 18 29 05
# Chromosome[ 2 ] = 06 05 00 08
# Chromosome[ 3 ] = 06 05 00 05
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 13 05 00 05
#
# Objective Function Value of each chromosome
# 18 129 18 6 6 13
#
#
# Generation  7  ends.
#
#
#
#
#
#
# Generation :  8
# Fitness
# 0.0526 0.0077 0.1429 0.0333 0.0476 0.0526
#
# Probability
# 0.1563 0.0228 0.4242 0.099 0.1414 0.1563
#
# Cumulative Probability
# 0.1563 0.1791 0.6033 0.7023 0.8437 1.0
#
# R[ 0 ] =  0.0038954719201333976
# R[ 1 ] =  0.7387292053331316
# R[ 2 ] =  0.1886110935517069
# R[ 3 ] =  0.9367277295860192
# R[ 4 ] =  0.3529758426059727
# R[ 5 ] =  0.8045594703239672
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 06 06 00 08
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 06 05 00 08
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 06 00 08
#
#
# Random Number
# 0.44 0.4986 0.8165 0.9291 0.2783 0.2779
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 06 06 00 08
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 06 05 00 08
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 06 00 08
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 16 18 29 05
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 13 13 00 05
# Chromosome[ 4 ] = 06 06 00 08
# Chromosome[ 5 ] = 06 05 00 08
#
# Objective Function Value of each chromosome
# 18 129 6 29 20 18
#
#
# Generation  8  ends.
#
#
#
#
#
#
# Generation :  9
# Fitness
# 0.0526 0.0175 0.1429 0.0127 0.1429 0.0476
#
# Probability
# 0.1265 0.0422 0.3433 0.0304 0.3433 0.1144
#
# Cumulative Probability
# 0.1265 0.1686 0.5119 0.5423 0.8856 1.0
#
# R[ 0 ] =  0.3693020070702223
# R[ 1 ] =  0.8902989919164803
# R[ 2 ] =  0.9041808688581029
# R[ 3 ] =  0.30407253894701014
# R[ 4 ] =  0.5623114854629337
# R[ 5 ] =  0.5058863804182955
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 06 06 00 08
# Chromosome[ 2 ] = 06 06 00 08
# Chromosome[ 3 ] = 06 05 00 05
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 05 00 05
#
#
# Random Number
# 0.3465 0.8104 0.3071 0.9645 0.0148 0.0558
#
# Parents
# 4 5
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 06 06 00 08
# Chromosome[ 2 ] = 06 06 00 08
# Chromosome[ 3 ] = 06 05 00 05
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 06 00 05
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 08
# Chromosome[ 1 ] = 06 24 00 08
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 06 05 20 08
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 06 00 08
#
# Objective Function Value of each chromosome
# 18 56 6 78 6 20
#
#
# Generation  9  ends.
#
#
#
#
#
#
# Generation :  10
# Fitness
# 0.1429 0.0286 0.0476 0.0217 0.0526 0.1111
#
# Probability
# 0.3531 0.0706 0.1177 0.0537 0.1301 0.2747
#
# Cumulative Probability
# 0.3531 0.4238 0.5415 0.5952 0.7253 1.0
#
# R[ 0 ] =  0.17083467619639758
# R[ 1 ] =  0.6798746712784257
# R[ 2 ] =  0.30553746136669646
# R[ 3 ] =  0.5032345596942476
# R[ 4 ] =  0.15272079569441288
# R[ 5 ] =  0.88318690812887
#
#
# New Chromosomes - Next Generation
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 06 05 00 08
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 06 06 00 08
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 06 00 05
#
#
# Random Number
# 0.4213 0.775 0.7553 0.9717 0.3868 0.4786
#
# Parents
#
# Chromosome After Crossover
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 06 05 00 08
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 06 06 00 08
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 06 00 05
#
# Chromosome Population after crossover and mutation
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 20 06 00 08
# Chromosome[ 2 ] = 06 06 00 08
# Chromosome[ 3 ] = 06 05 13 05
# Chromosome[ 4 ] = 06 05 00 08
# Chromosome[ 5 ] = 06 06 00 05
#
# Objective Function Value of each chromosome
# 6 34 20 45 18 8
#
#
# Generation  10  ends.

# %% [markdown]
# <b>RESULTS</b>

# %%
print('Number of Generations ->',count)
print('Best Chromosome obtained ->',chromosomeMatrix[findMin(chromosomeMatrix)])
# best chromosome is obtained when objective function becomes 0
print('Minimised Objective function for best Chromosome ->',0)
print('Final Chromosome Population')
printMatrix(chromosomeMatrix)
# Out:
# Number of Generations -> 10
# Best Chromosome obtained -> [6, 2, 0, 5]
# Minimised Objective function for best Chromosome -> 0
# Final Chromosome Population
# Chromosome[ 0 ] = 06 05 00 05
# Chromosome[ 1 ] = 06 05 00 08
# Chromosome[ 2 ] = 06 05 00 05
# Chromosome[ 3 ] = 06 06 14 08
# Chromosome[ 4 ] = 06 05 00 05
# Chromosome[ 5 ] = 06 02 00 05

# %% [markdown]
# <b>Few Points</b> :
# <ul>
#     <li>
# Above Chromosomes seem to be quiet uniform(similar gene values),this is due to low mutation rate, low mutation rate leads to fast convergence (less time to reach minimum objective function value).</li>
#     <li>
#         If mutation rate is kept high, values are quiet heterogenuous, but convergence might be slow.</li>
# </ul>
